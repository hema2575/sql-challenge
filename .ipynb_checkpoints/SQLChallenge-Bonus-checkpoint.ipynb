# %%
# %matplotlib notebook
import os
import pandas as pd

import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

pd.set_option('display.max_rows',5000)


from sqlalchemy import create_engine
from config import username, password

# %%
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/Employee')

connection = engine.connect()
print('connection established')
# Out:
# connection established

# %%
#!pip install psycopg2

# %%
employees_db = pd.read_sql('select * from employees', connection)
departments_db = pd.read_sql('select * from departments', connection)
dept_emp_db = pd.read_sql('select * from dept_emp', connection)
dept_manager_db = pd.read_sql('select * from dept_manager', connection)
salaries_db = pd.read_sql('select * from salaries', connection)
titles_db = pd.read_sql('select * from titles', connection)

# %%
employees_db.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053        e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444        e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786        s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238        e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18

# %%
departments_db.head()
# Out:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development

# %%
dept_emp_db.head()
# Out:
#    emp_no dept_no
# 0   10001    d005
# 1   10002    d007
# 2   10003    d004
# 3   10004    d004
# 4   10005    d003

# %%
dept_manager_db.head()
# Out:
#   dept_no  emp_no
# 0    d001  110022
# 1    d001  110039
# 2    d002  110085
# 3    d002  110114
# 4    d003  110183

# %%
salaries_db.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
titles_db
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
salemp_db = pd.merge(salaries_db, employees_db, how = 'inner', on='emp_no')
salemp_db.head()
# Out:
#    emp_no  salary emp_title_id  birth_date first_name last_name sex  \
# 0   10001   60117        e0003  1953-09-02     Georgi   Facello   M
# 1   10002   65828        s0001  1964-06-02    Bezalel    Simmel   F
# 2   10003   40006        e0003  1959-12-03      Parto   Bamford   M
# 3   10004   40054        e0003  1954-05-01  Chirstian   Koblick   M
# 4   10005   78228        s0001  1955-01-21    Kyoichi  Maliniak   M
#
#     hire_date
# 0  1986-06-26
# 1  1985-11-21
# 2  1986-08-28
# 3  1986-12-01
# 4  1989-09-12

# %%
salemp_db.rename(columns = {'emp_title_id' : 'title_id'}, inplace = True)
salemp_db.head()
# Out:
#    emp_no  salary title_id  birth_date first_name last_name sex   hire_date
# 0   10001   60117    e0003  1953-09-02     Georgi   Facello   M  1986-06-26
# 1   10002   65828    s0001  1964-06-02    Bezalel    Simmel   F  1985-11-21
# 2   10003   40006    e0003  1959-12-03      Parto   Bamford   M  1986-08-28
# 3   10004   40054    e0003  1954-05-01  Chirstian   Koblick   M  1986-12-01
# 4   10005   78228    s0001  1955-01-21    Kyoichi  Maliniak   M  1989-09-12

# %%
salemptitle_db = pd.merge(titles_db, salemp_db, how = 'inner', on='title_id')

# %%
salemptitle_db
# Out:
#        title_id    title  emp_no  salary  birth_date first_name    last_name  \
# 0         s0001    Staff   10002   65828  1964-06-02    Bezalel       Simmel
# 1         s0001    Staff   10005   78228  1955-01-21    Kyoichi     Maliniak
# 2         s0001    Staff   10007   56724  1957-05-23    Tzvetan    Zielinski
# 3         s0001    Staff   10011   42365  1953-11-07       Mary        Sluis
# 4         s0001    Staff   10016   70889  1961-05-02   Kazuhito  Cappelletti
# ...         ...      ...     ...     ...         ...        ...          ...
# 300019    m0001  Manager  111534   48077  1952-06-27     Hilary       Kambil
# 300020    m0001  Manager  111692   40000  1954-10-05      Tonny  Butterworth
# 300021    m0001  Manager  111784   40000  1956-06-14      Marjo   Giarratana
# 300022    m0001  Manager  111877   53846  1962-10-18    Xiaobin     Spinelli
# 300023    m0001  Manager  111939   40000  1960-03-25    Yuchang      Weedman
#
#        sex   hire_date
# ...

# %% [markdown]
# **Histogram of the most common salary ranges for employees**

# %%
# %matplotlib inline 
salary_emp = salemptitle_db['salary']

# Characterize the data set using matplotlib and stats.normaltest
plt.figure(figsize=(10,5),facecolor='white',edgecolor='blue')
plt.hist(salary_emp)

plt.xlabel('Salary')
plt.ylabel('Counts')
plt.savefig("Common Salary Ranges.png")
plt.show()
print(sts.normaltest(salemptitle_db['salary'].sample(100000)))
print("Mean salary :", salemptitle_db['salary'].mean())
print("Median of the salaries :", salemptitle_db['salary'].median())
print("Mode of the salaries :", salemptitle_db['salary'].mode())
# Out:
# NormaltestResult(statistic=14211.345652592625, pvalue=0.0)
# Mean salary : 52970.732451403885
# Median of the salaries : 48681.0
# Mode of the salaries : 0    40000
# dtype: int64

# %%
'''
We find that most staff have salaries in the range of $40000 to $50000.  Fewest employees are paid in the range $100,000 to $120,000. 
Also from the p value resulting from the normality test, the salaries do not appear to be normally distributed

'''
# Out:
# '\nWe find that most staff have salaries in the range of $40000 to $50000.  Fewest employees are paid in the range $100,000 to $120,000. \nAlso from the p value resulting from the normality test, the salaries do not appear to be normally distributed\n\n'

# %%
salemptitle = salemptitle_db.groupby(['title']).mean()['salary'].round(3)
salemptitle
# Out:
# title
# Assistant Engineer    48564.434
# Engineer              48535.337
# Manager               51531.042
# Senior Engineer       48506.800
# Senior Staff          58550.173
# Staff                 58465.383
# Technique Leader      48582.896
# Name: salary, dtype: float64

# %% [markdown]
# **Barchart of average salary by Title**

# %%
# Plot the Barchart
titles = salemptitle.index
avg_salary_per_title = salemptitle.values

x_axis = np.arange(len(titles))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, titles, rotation=90)
plt.title("Average Salary By Title")
plt.xlabel("Title")
plt.ylabel("Average Salary ($)")
plt.grid(axis="y")

chart = plt.bar(x_axis, avg_salary_per_title, color="g", alpha=0.5, align="center")

for i in chart:
    yvalue = i.get_height()
    plt.text(i.get_x(), yvalue + 500, "${:,.2f}K".format(yvalue/1000))

plt.savefig('Barchart of Average Salary by Title.png')
    
plt.show()

# %%
'''
# %matplotlib inline 

x_axis = np.arange(len(salemptitle_r_df))
tick_locations = [value for value in x_axis]

# Set x and y limits
#plt.xlim(-0.75, len(x_axis))
#plt.ylim(0, max(salemptitle_r_df["salary"])+20)

#plt.figure(figsize=(15,10))
#plt.bar(x_axis, salemptitle_r_df["salary"], color='r', alpha=0.5, align="center")

avgsalbytitle = salemptitle_r_df.plot(kind='bar',figsize=(10,5))   
plt.xticks(tick_locations, salemptitle_r_df["title"], rotation="vertical")
plt.title("Average salary by title")
plt.xlabel("Titles")
plt.ylabel("Average Salary")

for i in avgsalbytitle:
    yvalue = i.get_height()
    plt.text(i.get_x(), yvalue + 500, "${:,.2f}K".format(yvalue/1000))
    

plt.show()
'''
# Out:
# '\n%matplotlib inline \n\nx_axis = np.arange(len(salemptitle_r_df))\ntick_locations = [value for value in x_axis]\n\n# Set x and y limits\n#plt.xlim(-0.75, len(x_axis))\n#plt.ylim(0, max(salemptitle_r_df["salary"])+20)\n\n#plt.figure(figsize=(15,10))\n#plt.bar(x_axis, salemptitle_r_df["salary"], color=\'r\', alpha=0.5, align="center")\n\navgsalbytitle = salemptitle_r_df.plot(kind=\'bar\',figsize=(10,5))   \nplt.xticks(tick_locations, salemptitle_r_df["title"], rotation="vertical")\nplt.title("Average salary by title")\nplt.xlabel("Titles")\nplt.ylabel("Average Salary")\n\nfor i in avgsalbytitle:\n    yvalue = i.get_height()\n    plt.text(i.get_x(), yvalue + 500, "${:,.2f}K".format(yvalue/1000))\n    \n\nplt.show()\n'

# %%
'''
The average salaries of employees appear to be in the just less than $60,000. We see high mean salaries for titles Senior Staff and Staff. 
The lowest mean salary is just less than $50,000 and is drawn by titles Engineer, Assistant Engineer, Senior Engineer, Technique Leader. Followed by
a slight increase in salary for Manager. 
This gives ample proof to suspect that the data provided is not indicative of real world scenario. 

'''
